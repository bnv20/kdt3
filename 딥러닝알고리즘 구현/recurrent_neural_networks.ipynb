# %% [markdown]
# <a href="https://colab.research.google.com/github/bnv20/cakd3/blob/main/recurrent_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image('/content/drive/MyDrive/cakd3_colab/dl_keras/rnn1.jpg')
